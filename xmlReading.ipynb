# %%
from pullData import getDimensions, getCases, getDocuments, getParticulars, getSummary, getTonnage, scrapeSummaryByYear

# %%
getDimensions(1092464)
# Out:
#   VesselId DimensionTypeLookupId        DimensionTypeLookupName BreadthInFeet  \
# 0  1092464                     2                     Convention        105.80
# 1  1092464                     4       Hull(Overall) Simplified        105.80
# 2  1092464                     8  Length Between Perpendiculars           NaN
# 3  1092464                     9                   Design Draft           NaN
# 4  1092464                    10           Hull(Overall) Formal        105.80
# 5  1092464                    11                         Length           NaN
#
#   DepthInFeet LengthInFeet
# 0       59.10       623.40
# 1       59.10       623.30
# 2         NaN       608.90
# 3         NaN        42.10
# 4       59.10       623.30
# 5         NaN       623.30

# %%
getDocuments(1092464)
# Out:
#    VesselId                                     TypeLookupName  \
# 0   1092464      SOLAS Cargo Ship Safety Equipment Certificate
# 1   1092464                            Classification Document
# 2   1092464   SOLAS Cargo Ship Safety Construction Certificate
# 3   1092464          SOLAS Cargo Ship Safety Radio Certificate
# 4   1092464                ISM - Safety Management Certificate
# 5   1092464                       ISM - Document Of Compliance
# 6   1092464                International Load Line Certificate
# 7   1092464  International Oil Pollution Prevention Certifi...
# 8   1092464                       ISM - Document Of Compliance
# 9   1092464  International Oil Pollution Prevention Certifi...
# 10  1092464  International Oil Pollution Prevention Certifi...
# 11  1092464      SOLAS Cargo Ship Safety Equipment Certificate
# 12  1092464                ISM - Safety Management Certificate
# 13  1092464                       ISM - Document Of Compliance
# ...

# %%
getParticulars(1092464)
# Out:
#      VesselName VesselCallSign   ServiceType    ServiceSubType  \
# 0  MEDI SEGESTA          3FCG6  Freight Ship  Self-Discharging
#
#   StatusLookupName ConstructionCompletedYear Identification  \
# 0           Active                      2009        9403164
#
#   IdentificationTypeLookupId IdentificationTypeLookupName CountryLookupName  \
# 0                          2                   IMO Number            PANAMA
#
#   CountryLookupId
# 0          176886

# %%
getSummary({'vesselId': '1092464'})
# Out:
#   VesselId    VesselName VesselCallSign   ServiceType  \
# 0  1092464  MEDI SEGESTA          3FCG6  Freight Ship
#
#   ConstructionCompletedYear StatusLookupName Identification CountryLookupName
# 0                      2009           Active        9403164            PANAMA

# %%
getSummary({'service': 'School Ship'})
# Out:
#     VesselId                                  VesselName VesselCallSign  \
# 0       1692                                  SIX STRING        WDD7247
# 1       1773                                 SMITH POINT        WCZ9714
# 2       9122                              IRVING JOHNSON        WDB3153
# 3       9451                              ARUNG SAMUDERA            N/A
# 4       9690                                    ARETHUSA            N/A
# ..       ...                                         ...            ...
# 236  1632947  *DUPLICATE* USE PATRIOT STATE O.N. 1304085            N/A
# 237  1652152                                  MAKANI AHA            N/A
# 238  1654617                                    RENEGADE            N/A
# 239  1658170                              STATE OF MAINE            N/A
# 240  1658176                             LONE STAR STATE            N/A
#
#      ServiceType ConstructionCompletedYear StatusLookupName Identification  \
# ...

# %%
getParticulars(1692)
# Out:
#    VesselName VesselCallSign  ServiceType ServiceSubType StatusLookupName  \
# 0  SIX STRING        WDD7247  School Ship        General           Active
#
#   ConstructionCompletedYear Identification IdentificationTypeLookupId  \
# 0                      1982        1092464                          6
#
#   IdentificationTypeLookupName CountryLookupName CountryLookupId
# 0       Official Number (U.S.)     UNITED STATES          176948
